# %%
import pandas as pd
hr_df=pd.read_csv(r'C:\Users\Dell\Desktop\Data Science\projects\Predicting-which-of-your-Employee-will-Quit-your-Company-Data-Science-Project-master\hr_data.csv')

# %%
hr_df
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
# ...

# %%
# Numerical Analysis

# %%
hr_df.shape
# Out:
# (14999, 9)

# %%
hr_df.size
# Out:
# 134991

# %%
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            14999 non-null  int64
#  1   number_project         14999 non-null  int64
#  2   average_montly_hours   14999 non-null  int64
#  3   time_spend_company     14999 non-null  int64
#  4   Work_accident          14999 non-null  int64
#  5   left                   14999 non-null  int64
#  6   promotion_last_5years  14999 non-null  int64
#  7   department             14999 non-null  object
#  8   salary                 14999 non-null  object
# dtypes: int64(7), object(2)
# memory usage: 1.0+ MB

# %%
hr_df['department'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
hr_df['salary'].unique()
# Out:
# array(['low', 'medium', 'high'], dtype=object)

# %%
# Loading our Employee satisfaction data

# %%
s_df=pd.read_excel(r'C:\Users\Dell\Desktop\Data Science\projects\Predicting-which-of-your-Employee-will-Quit-your-Company-Data-Science-Project-master\employee_satisfaction_evaluation.xlsx')

# %%
s_df
# Out:
#        EMPLOYEE #  satisfaction_level  last_evaluation
# 0            1003                0.38             0.53
# 1            1005                0.80             0.86
# 2            1486                0.11             0.88
# 3            1038                0.72             0.87
# 4            1057                0.37             0.52
# ...           ...                 ...              ...
# 14994       87670                0.40             0.57
# 14995       87673                0.37             0.48
# 14996       87679                0.37             0.53
# 14997       87681                0.11             0.96
# 14998       87684                0.37             0.52
#
# [14999 rows x 3 columns]

# %%
main_df=hr_df.set_index('employee_id').join(s_df.set_index('EMPLOYEE #'))

# %%
main_df
# Out:
#              number_project  average_montly_hours  time_spend_company  \
# employee_id
# 1003                      2                   157                   3
# 1005                      5                   262                   6
# 1486                      7                   272                   4
# 1038                      5                   223                   5
# 1057                      2                   159                   3
# ...                     ...                   ...                 ...
# 87670                     2                   151                   3
# 87673                     2                   160                   3
# 87679                     2                   143                   3
# 87681                     6                   280                   4
# 87684                     2                   158                   3
#
#              Work_accident  left  promotion_last_5years department  salary  \
# employee_id
# ...

# %%
main_df=main_df.reset_index()

# %%
main_df
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
# ...

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            14999 non-null  int64
#  1   number_project         14999 non-null  int64
#  2   average_montly_hours   14999 non-null  int64
#  3   time_spend_company     14999 non-null  int64
#  4   Work_accident          14999 non-null  int64
#  5   left                   14999 non-null  int64
#  6   promotion_last_5years  14999 non-null  int64
#  7   department             14999 non-null  object
#  8   salary                 14999 non-null  object
#  9   satisfaction_level     14972 non-null  float64
#  10  last_evaluation        14972 non-null  float64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 1.3+ MB

# %%
main_df[main_df.isnull().any(axis=1)]
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 18            3794               2                   160                   3
# 19            1140               5                   262                   5
# 33            1230               2                   140                   3
# 53            1340               2                   132                   3
# 72           22316               2                   149                   3
# 92            1581               2                   143                   3
# 107          17376               2                   148                   3
# 120           1739               4                   158                   4
# 137           1847               2                   129                   3
# 175          32923               4                   164                   2
# 191           2160               4                   226                   6
# ...

# %%
main_df.describe()
# Out:
#         employee_id  number_project  average_montly_hours  time_spend_company  \
# count  14999.000000    14999.000000          14999.000000        14999.000000
# mean   45424.627575        3.803054            201.050337            3.498233
# std    25915.900127        1.232592             49.943099            1.460136
# min     1003.000000        2.000000             96.000000            2.000000
# 25%    22872.500000        3.000000            156.000000            3.000000
# 50%    45448.000000        4.000000            200.000000            3.000000
# 75%    67480.500000        5.000000            245.000000            4.000000
# max    99815.000000        7.000000            310.000000           10.000000
#
#        Work_accident          left  promotion_last_5years  satisfaction_level  \
# count   14999.000000  14999.000000           14999.000000        14972.000000
# mean        0.144610      0.238083               0.021268            0.612830
# ...

# %%
# filling null values with mean values

# %%
main_df.fillna(main_df.mean(),inplace=True)

# %%
main_df[main_df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [employee_id, number_project, average_montly_hours, time_spend_company, Work_accident, left, promotion_last_5years, department, salary, satisfaction_level, last_evaluation]
# Index: []

# %%
main_df.loc[main_df['employee_id']==3794]
# Out:
#     employee_id  number_project  average_montly_hours  time_spend_company  \
# 18         3794               2                   160                   3
#
#     Work_accident  left  promotion_last_5years department salary  \
# 18              1     1                      1      sales    low
#
#     satisfaction_level  last_evaluation
# 18             0.61283         0.716125

# %%
main_df.drop(columns='employee_id',inplace=True)

# %%
main_df
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  left  promotion_last_5years department  salary  \
# 0                  0     1                      0      sales     low
# ...

# %%
main_df.groupby('department').sum()
# Out:
#              number_project  average_montly_hours  time_spend_company  \
# department
# IT                     4683                248119                4256
# RandD                  3033                158030                2650
# accounting             2934                154292                2702
# hr                     2701                146828                2480
# management             2432                126787                2711
# marketing              3164                171073                3063
# product_mng            3434                180369                3135
# sales                 15634                831773               14631
# support                8479                447490                7563
# technical             10548                550793                9279
#
#              Work_accident  left  promotion_last_5years  satisfaction_level  \
# department
# IT                     164   273                      3           758.17283
# ...

# %%
main_df.groupby('department').mean()
# Out:
#              number_project  average_montly_hours  time_spend_company  \
# department
# IT                 3.816626            202.215974            3.468623
# RandD              3.853875            200.800508            3.367217
# accounting         3.825293            201.162973            3.522816
# hr                 3.654939            198.684709            3.355886
# management         3.860317            201.249206            4.303175
# marketing          3.687646            199.385781            3.569930
# product_mng        3.807095            199.965632            3.475610
# sales              3.776329            200.911353            3.534058
# support            3.803948            200.758188            3.393001
# technical          3.877941            202.497426            3.411397
#
#              Work_accident      left  promotion_last_5years  \
# department
# IT                0.133659  0.222494               0.002445
# ...

# %%
main_df['department'].value_counts()
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: department, dtype: int64

# %%
main_df['left'].value_counts()
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %%
# Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def plot_corr(df,size=10):
    
    corr=df.corr()
    fig,ax=plt.subplots(figsize=(size,size))
    ax.legend()
    cax=ax.matshow(corr)
    fig.colorbar(cax)
    plt.xticks(range(len(corr.columns)),corr.columns,rotation='vertical')
    plt.yticks(range(len(corr.columns)),corr.columns)
    
    
plot_corr(main_df)
# Out:
# No handles with labels found to put in legend.

# %%
plt.bar(x=main_df['left'],height=main_df['satisfaction_level'])
# Out:
# <BarContainer object of 14999 artists>

# %%
sns.barplot(x='left',y='satisfaction_level',data=main_df)

# %%
sns.barplot(x='promotion_last_5years',y='satisfaction_level',data=main_df,hue='left')

# %%
sns.pairplot(main_df)

# %%
#data preprocessing

# %%
y=main_df[['department','salary']]

# %%
y
# Out:
#       department  salary
# 0          sales     low
# 1          sales  medium
# 2          sales  medium
# 3          sales     low
# 4          sales     low
# ...          ...     ...
# 14994    support     low
# 14995    support     low
# 14996    support     low
# 14997    support     low
# 14998    support     low
#
# [14999 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

k=le.fit_transform(main_df['salary'])

# %%
k
# Out:
# array([1, 2, 2, ..., 1, 1, 1])

# %%
main_df
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  left  promotion_last_5years department  salary  \
# 0                  0     1                      0      sales     low
# ...

# %%
main_df['salary_num']=k

# %%
main_df
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  left  promotion_last_5years department  salary  \
# 0                  0     1                      0      sales     low
# ...

# %%
main_df.loc[main_df['salary']=='high']
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 72                  2                   149                   3
# 111                 6                   289                   4
# 189                 2                   156                   3
# 267                 2                   129                   3
# 306                 2                   149                   3
# ...               ...                   ...                 ...
# 14829               2                   148                   3
# 14868               2                   130                   3
# 14902               2                   159                   3
# 14941               2                   131                   3
# 14980               5                   238                   5
#
#        Work_accident  left  promotion_last_5years   department salary  \
# 72                 0     1                      0  product_mng   high
# ...

# %%
main_df.drop(['salary'],axis=1,inplace=True)

# %%
main_df
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  left  promotion_last_5years department  \
# 0                  0     1                      0      sales
# 1                  0     1                      0      sales
# ...

# %%
z=le.fit_transform(main_df['department'])

# %%
z
# Out:
# array([7, 7, 7, ..., 8, 8, 8])

# %%
main_df['department_num']=z

# %%
main_df
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  left  promotion_last_5years department  \
# 0                  0     1                      0      sales
# 1                  0     1                      0      sales
# ...

# %%
main_df.loc[main_df['department']=='hr']
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 31                  2                   134                   3
# 32                  2                   145                   3
# 33                  2                   140                   3
# 34                  4                   246                   6
# 108                 3                   177                   4
# ...               ...                   ...                 ...
# 14902               2                   159                   3
# 14975               7                   310                   4
# 14976               2                   136                   3
# 14977               4                   251                   6
# 14978               2                   144                   3
#
#        Work_accident  left  promotion_last_5years department  \
# 31                 0     1                      0         hr
# 32                 0     1                      0         hr
# ...

# %%
main_df.drop(['department'],axis=1,inplace=True)

# %%
main_df
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  left  promotion_last_5years  satisfaction_level  \
# 0                  0     1                      0                0.38
# ...

# %%
X=main_df.drop(['left'],axis=1)

# %%
X
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  promotion_last_5years  satisfaction_level  \
# 0                  0                      0                0.38
# 1                  0                      0                0.80
# ...

# %%
y=main_df['left']

# %%
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: left, Length: 14999, dtype: int64

# %%
y.size
# Out:
# 14999

# %%
# spliting data for training

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

# %%
X_train
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 8455                4                   145                   5
# 6403                5                   270                   3
# 9851                4                   158                   3
# 3087                4                   280                   5
# 11749               4                   240                   8
# ...               ...                   ...                 ...
# 10271               4                   152                   3
# 1815                7                   305                   4
# 7676                4                   175                   2
# 10722               4                   184                   3
# 10219               4                   224                   2
#
#        Work_accident  promotion_last_5years  satisfaction_level  \
# 8455               0                      0                0.66
# 6403               0                      0                0.68
# ...

# %%
X_test
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 14790               2                   159                   3
# 4469                3                   190                   3
# 4168                3                   122                   3
# 6931                3                   188                   5
# 12165               7                   296                   4
# ...               ...                   ...                 ...
# 4942                3                   124                   3
# 12105               7                   224                   5
# 6863                3                   171                   3
# 11021               4                   224                   3
# 7609                3                   214                   3
#
#        Work_accident  promotion_last_5years  satisfaction_level  \
# 14790              0                      0                0.39
# 4469               1                      0                0.68
# ...

# %%
y_test
# Out:
# 14790    1
# 4469     0
# 4168     0
# 6931     0
# 12165    1
#         ..
# 4942     0
# 12105    1
# 6863     0
# 11021    0
# 7609     0
# Name: left, Length: 4500, dtype: int64

# %%
#Model classifier

# %%
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

dt=DecisionTreeClassifier()

dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
from sklearn.metrics import accuracy_score

# %%
prediction_dt=dt.predict(X_test)

# %%
prediction_dt
# Out:
# array([1, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
prediction_dt.size
# Out:
# 4500

# %%
y_test
# Out:
# 14790    1
# 4469     0
# 4168     0
# 6931     0
# 12165    1
#         ..
# 4942     0
# 12105    1
# 6863     0
# 11021    0
# 7609     0
# Name: left, Length: 4500, dtype: int64

# %%
accuracy_dt=accuracy_score(y_test,prediction_dt)*100

# %%
accuracy_dt
# Out:
# 97.93333333333332

# %%
custom_dt=[[10,500,10,6,4,0.90,0.89,0,8]]

# %%
dt.predict(custom_dt)
# Out:
# array([0], dtype=int64)

# %%
Catagory=['Employee will stay','Employee will leave']

# %%
Catagory[int(dt.predict(custom_dt))]
# Out:
# 'Employee will stay'

# %%
# pedicting most important feature

# %%
dt.feature_importances_
# Out:
# array([1.03502641e-01, 9.50203463e-02, 1.40267071e-01, 8.68014811e-04,
#        2.57916381e-05, 5.00695675e-01, 1.41350023e-01, 5.75564951e-03,
#        1.25147875e-02])

# %%
feature_importance=pd.DataFrame(dt.feature_importances_,index=X_train.columns,columns=['Importance']).sort_values('Importance',ascending=False)

# %%
feature_importance
# Out:
#                        Importance
# satisfaction_level       0.500696
# last_evaluation          0.141350
# time_spend_company       0.140267
# number_project           0.103503
# average_montly_hours     0.095020
# department_num           0.012515
# salary_num               0.005756
# Work_accident            0.000868
# promotion_last_5years    0.000026

# %%
# KNN Algorithm

# %%
# Data Preprocessing of KNN

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler().fit(X_train)
X_train_std=sc.transform(X_train)
X_test_std=sc.transform(X_test)

# %%
X_train_std
# Out:
# array([[ 0.16135086, -1.12786186,  1.01745713, ..., -1.95759542,
#          1.05428122,  1.08527937],
#        [ 0.96918237,  1.38014026, -0.34594841, ..., -0.08917443,
#          1.05428122,  0.03963854],
#        [ 0.16135086, -0.86702964, -0.34594841, ..., -0.7898323 ,
#          1.05428122,  0.73673243],
#        ...,
#        [ 0.16135086, -0.52594135, -1.02765119, ..., -0.84822046,
#         -0.54967451,  1.08527937],
#        [ 0.16135086, -0.3453652 , -0.34594841, ..., -0.14756259,
#         -0.54967451,  1.08527937],
#        [ 0.16135086,  0.45719548, -1.02765119, ...,  1.02020052,
#         -0.54967451,  0.03963854]])

# %%
X_train
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 8455                4                   145                   5
# 6403                5                   270                   3
# 9851                4                   158                   3
# 3087                4                   280                   5
# 11749               4                   240                   8
# ...               ...                   ...                 ...
# 10271               4                   152                   3
# 1815                7                   305                   4
# 7676                4                   175                   2
# 10722               4                   184                   3
# 10219               4                   224                   2
#
#        Work_accident  promotion_last_5years  satisfaction_level  \
# 8455               0                      0                0.66
# 6403               0                      0                0.68
# ...

# %%
X_test
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 14790               2                   159                   3
# 4469                3                   190                   3
# 4168                3                   122                   3
# 6931                3                   188                   5
# 12165               7                   296                   4
# ...               ...                   ...                 ...
# 4942                3                   124                   3
# 12105               7                   224                   5
# 6863                3                   171                   3
# 11021               4                   224                   3
# 7609                3                   214                   3
#
#        Work_accident  promotion_last_5years  satisfaction_level  \
# 14790              0                      0                0.39
# 4469               1                      0                0.68
# ...

# %%
X_test_std
# Out:
# array([[-1.45431216, -0.84696562, -0.34594841, ..., -0.96499677,
#         -2.15363025,  1.08527937],
#        [-0.64648065, -0.2249811 , -0.34594841, ...,  0.2611545 ,
#          1.05428122,  1.08527937],
#        [-0.64648065, -1.58933424, -0.34594841, ...,  0.20276634,
#         -2.15363025,  0.73673243],
#        ...,
#        [-0.64648065, -0.60619742, -0.34594841, ...,  1.48730577,
#          1.05428122, -2.05164312],
#        [ 0.16135086,  0.45719548, -0.34594841, ...,  1.19536499,
#          1.05428122,  0.38818549],
#        [-0.64648065,  0.25655531, -0.34594841, ...,  0.20276634,
#          1.05428122,  0.73673243]])

# %%
from sklearn.neighbors import KNeighborsClassifier

knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train_std,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
prediction_knn=knn.predict(X_test_std)

# %%
accuracy_knn=accuracy_score(y_test,prediction_knn)*100

# %%
accuracy_knn
# Out:
# 95.35555555555555

# %%
# predicting which value of n_neighbors gives more accuracy

# %%
k_range=range(1,26)
scores={}
scores_list=[]

for k in k_range:
    knn=KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_std,y_train)
    prediction_knn=knn.predict(X_test_std)
    scores[k]=accuracy_score(y_test,prediction_knn)*100
    scores_list.append(accuracy_score(y_test,prediction_knn))

# %%
scores
# Out:
# {1: 96.4888888888889,
#  2: 96.28888888888889,
#  3: 95.35555555555555,
#  4: 95.37777777777777,
#  5: 95.11111111111111,
#  6: 95.51111111111112,
#  7: 95.15555555555557,
#  8: 95.26666666666667,
#  9: 94.8,
#  10: 94.86666666666666,
#  11: 94.6,
#  12: 94.86666666666666,
#  13: 94.55555555555556,
#  14: 94.77777777777779,
#  15: 94.5111111111111,
#  16: 94.44444444444444,
#  17: 94.24444444444444,
#  18: 94.44444444444444,
#  19: 94.15555555555557,
#  20: 94.31111111111112,
#  21: 94.08888888888889,
#  22: 94.17777777777778,
#  23: 94.02222222222221,
#  24: 94.11111111111111,
#  25: 94.0}

# %%
scores_list
# Out:
# [0.9648888888888889,
#  0.9628888888888889,
#  0.9535555555555556,
#  0.9537777777777777,
#  0.9511111111111111,
#  0.9551111111111111,
#  0.9515555555555556,
#  0.9526666666666667,
#  0.948,
#  0.9486666666666667,
#  0.946,
#  0.9486666666666667,
#  0.9455555555555556,
#  0.9477777777777778,
#  0.9451111111111111,
#  0.9444444444444444,
#  0.9424444444444444,
#  0.9444444444444444,
#  0.9415555555555556,
#  0.9431111111111111,
#  0.9408888888888889,
#  0.9417777777777778,
#  0.9402222222222222,
#  0.9411111111111111,
#  0.94]

# %%
plt.plot(k_range,scores_list)

# %%
import numpy as np

# %%
X_knn=np.array([[10,500,10,6,4,0.90,0.89,0,8]])
X_knn_std=sc.transform(X_knn)

# %%
X_knn_std
# Out:
# array([[ 5.00833992,  5.99486415,  4.425971  , 16.63527561, 28.0337788 ,
#          1.15535425,  1.02020052, -2.15363025,  0.73673243]])

# %%
X_knn_prediction=knn.predict(X_knn_std)

# %%
X_knn_prediction
# Out:
# array([0], dtype=int64)

# %%
Catagory[int(X_knn_prediction)]
# Out:
# 'Employee will stay'

# %%
# comparing algorithms

# %%
algorithms=['Decision Tree','KNN']
scores=[accuracy_dt,accuracy_knn]
plt.xlabel("Algorithms")
plt.ylabel("Accuracy Score")
sns.barplot(algorithms,scores)
plt.show()
